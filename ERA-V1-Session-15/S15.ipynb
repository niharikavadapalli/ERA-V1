# %%
! git clone https://github.com/niharikavadapalli/ERA-V1.git
# !git -C ERA-V1 pull

! pip install --quiet "pandas" "torch" "torchvision" "ipython[notebook]" "seaborn" "pytorch-lightning>=1.4" "torchmetrics>=0.6" "lightning-bolts" "torch-lr-finder" "grad-cam" "gradio" "torchinfo"
# Out:
# Cloning into 'ERA-V1'...
# remote: Enumerating objects: 845, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 845 (delta 14), reused 28 (delta 10), pack-reused 808
# Receiving objects: 100% (845/845), 45.50 MiB | 24.20 MiB/s, done.
# Resolving deltas: 100% (413/413), done.
# Already up to date.

# %%
import sys
sys.path.append("ERA-V1/ERA-V1-Session-15")

from config import get_config
from train import train_model
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
config = get_config()
config['batch_size'] = 16
config['d_model'] = 512
config['preload'] = None
config['num_epochs'] = 10

# %%
train_model(config)
# Out:
# using device: cuda
# Downloading builder script:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/7.98k [00:00<?, ?B/s]
# Downloading and preparing dataset opus_books/en-it (download: 3.14 MiB, generated: 8.58 MiB, post-processed: Unknown size, total: 11.72 MiB) to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf...
# Downloading data:   0%|          | 0.00/3.30M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Max length of source sentence: 309
# Max length of target sentence: 274
# processing epoch 00: 100%|██████████| 1819/1819 [24:31<00:00,  1.24it/s, loss=6.133]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: I had wakened the glow: his features beamed.
#     TARGET: Aveva riaccesa la fiamma dal volto, ero raggiante.
#  PREDICTED: E il suo momento , ma non si .
# --------------------------------------------------------------------------------
#     SOURCE: Kitty was not in the bed beside him.
#     TARGET: Kitty non era nel letto accanto a lui.
#  PREDICTED: E il viso , e si era un ’ ic .
# --------------------------------------------------------------------------------
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `CharErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `CharErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `WordErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `WordErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `BLEUScore` from `torchmetrics` was deprecated and will be removed in 2.0. Import `BLEUScore` from `torchmetrics.text` instead.
#   _future_warning(
# processing epoch 01: 100%|██████████| 1819/1819 [24:48<00:00,  1.22it/s, loss=5.616]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: But not so much from illness as from pride, as the Princess Shcherbatskaya explained – Madame Stahl was not acquainted with any of the Russians there.
#     TARGET: Ma non tanto per la malattia, quanto per alterigia, così spiegava la principessa, la signora Stahl non trattava nessuno dei russi.
#  PREDICTED: Ma non si poteva essere in modo di nuovo , ma non si poteva essere in modo di nuovo , ma non si .
# --------------------------------------------------------------------------------
#     SOURCE: I mention political economy; you say it makes things worse.
#     TARGET: E così siamo anche noi, io e voi.
#  PREDICTED: Mi a me , Jane , .
# --------------------------------------------------------------------------------
# processing epoch 02: 100%|██████████| 1819/1819 [24:47<00:00,  1.22it/s, loss=5.430]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE

# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: In another moment I was within that apartment.
#     TARGET: Un momento dopo ero entrata.
#  PREDICTED: In un momento mi sentii in silenzio .
# --------------------------------------------------------------------------------
#     SOURCE: 'Your health is still not good?'
#     TARGET: — La vostra salute è sempre poco buona?
#  PREDICTED: — La tua salute non è vero ?
# --------------------------------------------------------------------------------
# processing epoch 06: 100%|██████████| 1819/1819 [24:57<00:00,  1.21it/s, loss=4.092]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He was aware that the teacher himself did not believe what he was saying; he felt that by the tone in which the words were uttered.
#     TARGET: Egli capiva che il maestro non pensava a quello che diceva; lo sentiva dal tono con cui le parole erano dette.
#  PREDICTED: Egli capì che il racconto non si poteva dire quello che diceva , e sentiva che le parole erano le parole :
# --------------------------------------------------------------------------------
#     SOURCE: Life, however, was yet in my possession, with all its requirements, and pains, and responsibilities.
#     TARGET: Ma la vita mi apparteneva ancora, con tutti i suoi attributi di dolore e di responsabilità;
#  PREDICTED: La mia vita era in me , ma con tutte le mie forze e la sua volontà si mise a piangere .
# --------------------------------------------------------------------------------
# processing epoch 07: 100%|██████████| 1819/1819 [24:56<00:00,  1.22it/s, loss=4.052]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Serezha's eyes, that had been shining with affection and joy, grew dull and drooped under his father's gaze.
#     TARGET: Gli occhi scintillanti di tenerezza e di felicità di Serëza si spensero e si abbassarono sotto lo sguardo del padre.
#  PREDICTED: La figura di Serëza , che era stata innamorata di una gioia e forte , si fece pensieroso .
# --------------------------------------------------------------------------------
#     SOURCE: Everything about this baby was sweet, but for some reason she did not grip the heart.
#     TARGET: Tutto in quella bambina era grazioso, eppure, chi sa perché, non le prendeva il cuore.
#  PREDICTED: Tutto questo era bello , ma per questo non era possibile , per il cuore non era più bello .
# --------------------------------------------------------------------------------
# processing epoch 08: 100%|██████████| 1819/1819 [24:53<00:00,  1.22it/s, loss=3.566]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: 'Now he has received my note and is on his way back.
#     TARGET: “Adesso ha già ricevuto il biglietto e torna indietro.
#  PREDICTED: — Ecco , è contento della mia lettera e ha portato il suo biglietto .
# --------------------------------------------------------------------------------
#     SOURCE: Mlle Linon hurriedly left him and went toward the other door.
#     TARGET: M.lle Linon si affrettò a lasciarlo e andò verso un’altra porta.
#  PREDICTED: lle Linon si avvicinò e andò subito senza staccare l ’ altra porta .
# --------------------------------------------------------------------------------
# processing epoch 09: 100%|██████████| 1819/1819 [24:54<00:00,  1.22it/s, loss=3.251]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Utter it, Jane: but I wish that instead of a mere inquiry into, perhaps, a secret, it was a wish for half my estate." "Now, King Ahasuerus! What do I want with half your estate?
#     TARGET: — Parlate, dunque, ma vorrei che invece di farmi una semplice domanda curiosa, alla quale forse è legato un segreto, mi aveste chiesto la metà delle mie ricchezze. — Ebbene, re Assuero, che cosa farei della metà del vostro patrimonio?
#  PREDICTED: — , Jane , ma vorrei che un vero simile abbia fatto una sola cosa in cui è una sola creatura , se non volete , — disse il Re , — che cosa voglio con la vostra missione in mezzo ?
# --------------------------------------------------------------------------------
#     SOURCE: "Has anything happened here?
#     TARGET: — È forse accaduto qualcosa qui?
#  PREDICTED: — È accaduto qualcosa che vi ha fatto qui ?
# --------------------------------------------------------------------------------
